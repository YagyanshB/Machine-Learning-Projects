# %% [markdown]
# <a href="https://colab.research.google.com/github/YagyanshB/Machine-Learning-Projects/blob/main/Keywords_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
# !pip install pytrends
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
trends.build_payload(kw_list=["Data Science"])
data = trends.interest_by_region()
print(data.sample(10))
# Out:
#               Data Science
# geoName
# Philippines             36
# Algeria                 11
# Türkiye                  5
# Réunion                  0
# Guernsey                 0
# Georgia                  0
# Saudi Arabia            14
# Albania                  0
# Martinique               0
# Eswatini                 0

# %%
df = data.sample(15)
df.reset_index().plot(x="geoName", y="Data Science", figsize=(8,4), kind="bar")
plt.show()

# %%
data = trends.trending_searches(pn="india")
print(data.head(10))
# Out:
#                                   0
# 0  Kisi Ka Bhai Kisi Ki Jaan Review
# 1             Sevilla vs Man United
# 2                      Ramadan 2023
# 3           Virupaksha Movie Review
# 4                         Evil Dead
# 5                      Saudi Arabia
# 6              Sporting vs Juventus
# 7                        Eid Wishes
# 8                         Mammootty
# 9                             Saket

# %%
keyword = trends.suggestions(keyword="Programming")
data = pd.DataFrame(keyword)
print(data.head())
# Out:
#              mid                                              title  \
# 0       /m/0kc6x                                               ESPN
# 1   /g/113qgc5t1                                          Luc Bodin
# 2      /m/04m55x                                               WLBZ
# 3      /m/06rpx4                                               KVEW
# 4  /g/11fx8y_lzq  Mastering Bitcoin: Programming the Open Blockc...
#
#                            type
# 0                 Cable company
# 1                        Author
# 2            Television station
# 3            Television station
# 4  Book by Andreas Antonopoulos
